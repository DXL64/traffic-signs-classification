# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
# Out:
# 2024-11-14 11:23:35.036130: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-14 11:23:35.049277: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-14 11:23:35.053137: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-14 11:23:35.062667: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-14 11:23:35.930911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data_info = pd.read_csv(os.path.join('vndata', 'classes.csv'))

for data in data_info:
    print(data)
# Out:
# filename
#  101_DuongCam
#  102_CamDiNguocChieu
#  103a_CamOTo
#  103b_CamOToRePhai
#  103c_CamOToReTrai
#  104_CamXeMay
#  105_CamOTovaXeMay
#  106a_CamXeTai
#  106b_CamXeTaiTren2.5tan
#  107_CamOToKhachvaOTo
#  108_CamOToRoMooc
#  109_CamMayKeo
#  110a_CamXeDap
#  110b_CamXeDapTho
#  111_CamXe3_4banhthoso
#  112_CamNguoiDiBo
#  113_CamXeKeoDay
#  114_CamXeSucVatKeo
#  115_HanCheTrongLuongXe
#  116_HanCheTrongLuongTrucXe
#  117_HanCheChieuCaoXe
#  118_HanCheChieuRongXe
#  119_HanCheChieuDaiOTo
#  120_HanCheChieuDaiRoMooc
#  121_KhoangCachToiThieuGiuaHaiXe
#  122_DungLai
#  123_CamReTrai
#  124_CamRePhai
#  125_CamQuayDau
#  126_CamOToQuayDau
#  127_CamVuot
#  128_CamOToVuot
#  129_TocDoToiDa
#  130_CamBopCoi
#  131_TramThueQuan
#  132_CamDungVaDoXe
#  133_CamDoXe
#  134_CamDoXeNgayLe
#  135_CamDoXeNgayChan
#  136_NhuongDuongChoXeCoGioiDiNguocChieuTrongDuongHep
#  137_HetCamVuot
#  138_HetHanCheToiDa
#  139_HetTatCaCacLenhCam
#  140_CamDiThang
#  141_CamReTraiVaPhai
#  142_CamDiThangVaRePhai
#  143_CamDiThangVaReTrai
#  144_CamXeCongNong
#  201a_ChoNgoacVongBenTrai
#  201b_ChoNgoacVongBenPhai
#  202_NhieuChoNgoacNguyHienLienTiep
#  203a_DuongHepHaiBen
#  203b_DuongHepBenTrai
#  203c_DuongHepBenPhai
#  204_Duong2Chieu
#  205a_DuongCatNhau
#  205b_DuongCatNhauTrai
#  205c_DuongCatNhauPhai
#  205d_DuongCatNhauChuT
#  205e_DuongCatNhauChuY
#  206_DuongGiaoNhauVongTuyen
#  207a_GiaNhauVoiDuongKhongUuTien
#  207b_GiaoNhauVoiDuongKhongUuTien
#  207c_GiaoNhauVoiDuongKhongUuTien
#  208_GiaoNhauVoiDuongUuTien
#  209_GiaoNhauVoiTinHieuDen
#  210_GiaoVoiDuongSatCoRaoChan
#  211_GiaoVoiDuongSatKhongCoRaoChan
#  212_CauHep
#  213_CauTam
#  214_CauXoay-CauDat
#  215_KeVucSauPhiaTruoc
#  216_DuongNgam
#  217_BenPha
#  218_CuaChui
#  219_DocXuongNguyHiem
#  220_DocLenNguyHiem
#  221_DuongKhongBangPhang
#  222_DuongTronTruot
#  223_VachNuiNguyHiem
#  224_NguoiDiBoCatNgang
#  225_TreEm
#  226_NguoiDiXeDapCatNgang
#  227_CongTruong
#  228_DaLo
#  229_DaiMayBay
#  230_GiaSuc
#  231_ThuRungDiNgang
#  232_GioNgang
#  234_NguyHiemKhac
#  235_GiaoNhauVoiDuongHaiChieu
#  236_DuongDoi
#  237_HetDuongDoi
#  238_CauVong
#  239_DuongCapDienPhiaTren
#  240_DuongCaoTocPhiaTruoc
#  241_DuongHam
#  242_ChoDuongSatCatDuongBo
#  243_DuongSatCatDuongBoKhongVuongGoc
#  244_DoanDuongHayXayRaTaiNan
#  245_DiCham
#  246a_VongTranhHaiBen
#  246b_VongTranhBenTrai
#  246c_VongTranhBenPhai
#  301a_CacXeChiDuocDiThang
#  301b_CacXeChiDUocRePhai
#  301c_CacXeChiDUocReTrai
#  301d_CacXeChiDUocRePhai
#  301e_CacXeChiDUocReTrai
#  301f_CacXeChiDiThang-RePhai
#  301h_CacXeChiDiThang-ReTrai
#  301i_CacXeChiReTrai-RePhai
#  302a_HuongDiVongChuongNgaiVatSangPhai
#  302b_HuongDiVongChuongNgaiVatSangTrai
#  303_NoiGiaoNhauChayTheoVongTuyen
#  304_DuongDanhChoXeThoSo
#  305_DuongDanhChoNguoiDiBo
#  306_TocDoToiThieuChoPhep
#  307_HetHanCheTocDoToiThieu
#  308_TuyenDuongCauVuotBatQua
#  309_AnCoi
